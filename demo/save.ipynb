# %%
import cv2
import os
from glob import glob
from ultralytics import solutions
import imageio

# --- CONFIG ---
IMAGE_FOLDER = "../data_test_models/UFPR04"
MODEL_PATH = "../models/best.pt"
SLOT_JSON = "../slots/UFPR04.json"
FPS = 3  # ảnh/giây
GIF_OUTPUT = "output_parking.gif"

# --- Load model parking ---
parkingmanager = solutions.ParkingManagement(
    model=MODEL_PATH,
    json_file=SLOT_JSON
)

# --- Load Image List ---
image_paths = sorted(glob(os.path.join(IMAGE_FOLDER, "*.jpg")))

# --- Prepare to save GIF ---
frames_for_gif = []

# --- Process each image ---
for img_path in image_paths:
    img = cv2.imread(img_path)
    if img is None:
        continue

    # Predicting occupancy slot
    results = parkingmanager(img)

    # Show image
    cv2.imshow("Smart Parking Lot", results.plot_im)

    # Save frame for GIF
    frame_rgb = cv2.cvtColor(results.plot_im, cv2.COLOR_BGR2RGB)
    frames_for_gif.append(frame_rgb)

    if cv2.waitKey(int(1000 / FPS)) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()

# --- Save to GIF ---
imageio.mimsave(GIF_OUTPUT, frames_for_gif, fps=FPS)
print(f"✅ Đã lưu GIF tại: {GIF_OUTPUT}")
# Out:
# Ultralytics Solutions:  {'source': None, 'model': '../models/best.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': None, 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': '../slots/UFPR04.json', 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': False, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}
# 0: 720x1280 102.5ms
# Speed: 467.6ms track, 102.5ms solution per image at shape (1, 3, 720, 1280)
#
# 1: 720x1280 97.5ms
# Speed: 539.4ms track, 97.5ms solution per image at shape (1, 3, 720, 1280)
#
# 2: 720x1280 112.5ms
# Speed: 396.4ms track, 112.5ms solution per image at shape (1, 3, 720, 1280)
#
# 3: 720x1280 99.5ms
# Speed: 431.4ms track, 99.5ms solution per image at shape (1, 3, 720, 1280)
#
# 4: 720x1280 112.0ms
# Speed: 384.0ms track, 112.0ms solution per image at shape (1, 3, 720, 1280)
#
# 5: 720x1280 100.7ms
# Speed: 335.3ms track, 100.7ms solution per image at shape (1, 3, 720, 1280)
#
# 6: 720x1280 97.9ms
# Speed: 327.9ms track, 97.9ms solution per image at shape (1, 3, 720, 1280)
#
# 7: 720x1280 94.0ms
# Speed: 345.7ms track, 94.0ms solution per image at shape (1, 3, 720, 1280)
#
# 8: 720x1280 93.1ms
# Speed: 292.0ms track, 93.1ms solution per image at shape (1, 3, 720, 1280)
#
# 9: 720x1280 93.7ms
# Speed: 315.0ms track, 93.7ms solution per image at shape (1, 3, 720, 1280)
#
# 10: 720x1280 95.2ms
# Speed: 303.7ms track, 95.2ms solution per image at shape (1, 3, 720, 1280)
#
# 11: 720x1280 84.4ms
# Speed: 244.8ms track, 84.4ms solution per image at shape (1, 3, 720, 1280)
#
# 12: 720x1280 74.4ms
# Speed: 246.9ms track, 74.4ms solution per image at shape (1, 3, 720, 1280)
#
# 13: 720x1280 89.1ms
# Speed: 262.0ms track, 89.1ms solution per image at shape (1, 3, 720, 1280)
#
# 14: 720x1280 137.8ms
# Speed: 247.2ms track, 137.8ms solution per image at shape (1, 3, 720, 1280)
#
# 15: 720x1280 113.6ms
# Speed: 239.4ms track, 113.6ms solution per image at shape (1, 3, 720, 1280)
#
# 16: 720x1280 126.3ms
# Speed: 323.1ms track, 126.3ms solution per image at shape (1, 3, 720, 1280)
#
# 17: 720x1280 100.5ms
# Speed: 258.4ms track, 100.5ms solution per image at shape (1, 3, 720, 1280)
#
# 18: 720x1280 80.9ms
# Speed: 269.6ms track, 80.9ms solution per image at shape (1, 3, 720, 1280)
#
# 19: 720x1280 75.9ms
# Speed: 240.9ms track, 75.9ms solution per image at shape (1, 3, 720, 1280)
#
# 20: 720x1280 86.5ms
# Speed: 381.5ms track, 86.5ms solution per image at shape (1, 3, 720, 1280)
#
# 21: 720x1280 79.4ms
# Speed: 3561.0ms track, 79.4ms solution per image at shape (1, 3, 720, 1280)
#
# 22: 720x1280 73.3ms
# Speed: 1760.8ms track, 73.3ms solution per image at shape (1, 3, 720, 1280)
#
# 23: 720x1280 74.7ms
# Speed: 275.9ms track, 74.7ms solution per image at shape (1, 3, 720, 1280)
#
# 24: 720x1280 69.7ms
# Speed: 224.0ms track, 69.7ms solution per image at shape (1, 3, 720, 1280)
#
# 25: 720x1280 63.9ms
# Speed: 221.1ms track, 63.9ms solution per image at shape (1, 3, 720, 1280)
#
# 26: 720x1280 55.7ms
# Speed: 229.3ms track, 55.7ms solution per image at shape (1, 3, 720, 1280)
#
# 27: 720x1280 58.4ms
# Speed: 217.5ms track, 58.4ms solution per image at shape (1, 3, 720, 1280)
#
# 28: 720x1280 54.2ms
# Speed: 216.7ms track, 54.2ms solution per image at shape (1, 3, 720, 1280)
#
# 29: 720x1280 52.9ms
# Speed: 221.5ms track, 52.9ms solution per image at shape (1, 3, 720, 1280)
#
# 30: 720x1280 48.2ms
# Speed: 244.0ms track, 48.2ms solution per image at shape (1, 3, 720, 1280)
#
# 31: 720x1280 49.0ms
# Speed: 215.1ms track, 49.0ms solution per image at shape (1, 3, 720, 1280)
#
# 32: 720x1280 42.4ms
# Speed: 217.4ms track, 42.4ms solution per image at shape (1, 3, 720, 1280)
#
# 33: 720x1280 41.4ms
# Speed: 219.1ms track, 41.4ms solution per image at shape (1, 3, 720, 1280)
#
# 34: 720x1280 42.2ms
# Speed: 213.7ms track, 42.2ms solution per image at shape (1, 3, 720, 1280)
#
# 35: 720x1280 49.0ms
# Speed: 222.4ms track, 49.0ms solution per image at shape (1, 3, 720, 1280)
#
# 36: 720x1280 48.8ms
# Speed: 217.4ms track, 48.8ms solution per image at shape (1, 3, 720, 1280)
#
# 37: 720x1280 53.6ms
# Speed: 223.6ms track, 53.6ms solution per image at shape (1, 3, 720, 1280)
#
# 38: 720x1280 53.1ms
# Speed: 214.3ms track, 53.1ms solution per image at shape (1, 3, 720, 1280)
#
# 39: 720x1280 55.8ms
# Speed: 217.9ms track, 55.8ms solution per image at shape (1, 3, 720, 1280)
#
# 40: 720x1280 52.5ms
# Speed: 219.2ms track, 52.5ms solution per image at shape (1, 3, 720, 1280)
#
# 41: 720x1280 51.1ms
# Speed: 221.4ms track, 51.1ms solution per image at shape (1, 3, 720, 1280)
#
# 42: 720x1280 48.3ms
# Speed: 215.9ms track, 48.3ms solution per image at shape (1, 3, 720, 1280)
#
# ✅ Đã lưu GIF tại: output_parking.gif
